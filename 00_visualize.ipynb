# %%
# default_exp visualize

# %% [markdown]
# # Visualize
#
# > API details.

# %%
#hide
from nbdev.showdoc import *

# %%
#export
import matplotlib.pyplot as plt
import numpy as np

def plot_images(images,
                labels=None,
                cls_true=None,
                cls_pred=None,
                space=(0.3, 0.3),
                mxn=None,
                size=(5, 5),
                dpi=300,
                max_w=1500,
                out_file=None,
                cmap='binary'):

    if mxn is None:
        # n = max(max_w // max([img.shape[1] for img in images]), 1)
        n = int(np.sqrt(len(images)))
        n = min(n, len(images))
        m = len(images) // n
        m = max(1, m)
        mxn = (m, n)
        print(mxn)

    fig, axes = plt.subplots(*mxn)
    fig.subplots_adjust(hspace=space[0], wspace=space[1])
    fig.figsize = size
    fig.dpi = dpi
    for i, ax in enumerate(axes.flat):
        if i < len(images):
            ax.imshow(images[i], cmap=cmap)
            if labels is not None:
                xlabel = labels[i]
            elif cls_pred is None and cls_true is not None:
                xlabel = "True: {0}".format(cls_true[i])
            elif cls_pred is None and cls_true is not None:
                xlabel = "True: {0}, Pred: {1}".format(cls_true[i],
                                                       cls_pred[i])
            else:
                xlabel = None
            if xlabel is not None:
                ax.set_xlabel(xlabel)
            ax.set_xticks([])
            ax.set_yticks([])
    if out_file is None:
        plt.show()
    else:
        plt.savefig(out_file)
        print('Save fig:', out_file)
    plt.close()

# %%
show_doc(plot_images)
# Out:
# <h4 id="plot_images" class="doc_header"><code>plot_images</code><a href="__main__.py#L5" class="source_link" style="float:right">[source]</a></h4>
#
# > <code>plot_images</code>(**`images`**, **`labels`**=*`None`*, **`cls_true`**=*`None`*, **`cls_pred`**=*`None`*, **`space`**=*`(0.3, 0.3)`*, **`mxn`**=*`None`*, **`size`**=*`(5, 5)`*, **`dpi`**=*`300`*, **`max_w`**=*`1500`*, **`out_file`**=*`None`*, **`cmap`**=*`'binary'`*)

# %%
from glob import glob
import mmcv
from avcv.visualize import *
paths = glob('/data/synthetic/SHARE_SVA_DATASET/val/000/frames/*')
imgs = [mmcv.imread(path, channel_order='rgb') for path in np.random.choice(paths, 10)]
plot_images(imgs)
# Out:
# (3, 3)

# %%
#export 

import cv2
import matplotlib.pyplot as plt

def show(inp, dpi=80, size=10, cmap='gray', out_file=None):    
    inp = mmcv.imread(inp)
    if len(inp.shape) == 4:
        inp = inp[0]
    if size is None:
        size = max(5, inp.shape[1] // 65)
    plt.figure(figsize=(size, size), dpi=dpi)
    plt.imshow(inp, cmap=cmap)
    if out_file is None:
        plt.show()
    else:
        plt.savefig(out_file)
    plt.close()

# %%
show_doc(show)
# Out:
# <h4 id="show" class="doc_header"><code>show</code><a href="__main__.py#L6" class="source_link" style="float:right">[source]</a></h4>
#
# > <code>show</code>(**`inp`**, **`dpi`**=*`80`*, **`size`**=*`10`*, **`cmap`**=*`'gray'`*, **`out_file`**=*`None`*)

# %%
# From path
show('/data/synthetic/SHARE_SVA_DATASET/val/000/frames/000001_b.jpg', dpi=50)

# %%
# From numpy
img = mmcv.imread('/data/synthetic/SHARE_SVA_DATASET/val/000/frames/000001_b.jpg')
show(img, dpi=50)
