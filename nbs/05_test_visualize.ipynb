# %%
cd ~/gitprojects/traffic-sign-models-dev/data-manager/sample-videos/
# Out:
# /Users/bi/gitprojects/traffic-sign-models-dev/data-manager/sample-videos

# %%
from avcv.coco import *

gt = AvCOCO('./video_1114/annotations/default.json')
pred = gt.loadRes('./video_1114/annotations/default_s_pred.json')
# Out:
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!
# Loading and preparing results...
# DONE (t=0.00s)
# creating index...
# index created!

# %%
ds = CocoDataset(pred.dataset, './video_1114/images/')
# Out:
# loading annotations into memory...
# Done (t=0.00s)
# creating index...
# index created!

# %%
ds.visualize(show=1, dpi=300, img_id=23);
